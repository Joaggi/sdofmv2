# %%
import pandas as pd

# %%
base_path = "../../../assets/test_results/"
columns = ["channel", "rmse_intensity", ]
aia=pd.read_csv(base_path + "sdofmv2-aia-test-results.csv")
all=pd.read_csv(base_path + "sdofmv2-all-test-results.csv")
hmi=pd.read_csv(base_path + "sdofmv2-hmi-test-results.csv")
all_large=pd.read_csv(base_path + "sdofmv2-large-all-test-results.csv")
all_small=pd.read_csv(base_path + "sdofmv2-small-all-test-results.csv")

# %%
aia
# Out:
#   channel  rmse_intensity  flux_difference    ppe10s    ppe50s  r2_score  \
# 0    131A        0.347877         0.049133  0.221034  0.651534  0.852238
# 1   1600A        0.482322        -0.013439  0.149065  0.557276  0.762373
# 2   1700A        0.342694         0.087475  0.219688  0.671376  0.878781
# 3    171A        0.358874         0.250590  0.241057  0.654076  0.854982
# 4    193A        0.246063         0.005004  0.362648  0.774423  0.924055
# 5    211A        0.198372         0.008110  0.437550  0.833511  0.936964
# 6    304A        0.522731         0.454293  0.156623  0.511725  0.687896
# 7    335A        0.242682         0.010138  0.278938  0.728811  0.885595
# 8     94A        0.276530         0.018379  0.226219  0.697794  0.872027
#
#    pixel_correlation
# 0           0.923068
# 1           0.873213
# 2           0.937964
# 3           0.924779
# 4           0.961411
# 5           0.967986
# 6           0.828282
# 7           0.940035
# 8           0.933779
